# %%
# !pip install transformers pymongo torch
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: transformers in /opt/homebrew/lib/python3.9/site-packages (4.43.3)
# Requirement already satisfied: pymongo in /opt/homebrew/lib/python3.9/site-packages (4.8.0)
# Requirement already satisfied: torch in /opt/homebrew/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.9/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (0.24.2)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (2022.1.18)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.9/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/homebrew/lib/python3.9/site-packages (from pymongo) (2.6.1)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.9/site-packages (from torch) (4.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.9/site-packages (from requests->transformers) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.9/site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.9/site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.9/site-packages (from requests->transformers) (2021.10.8)
# WARNING: Error parsing dependencies of bleach: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     tinycss2 (>=1.1.0<1.2) ; extra == 'css'
#              ~~~~~~~~^
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
# !brew services start mongodb-community
# Out:
# Service `mongodb-community` already started, use `brew services restart mongodb-community` to restart.

# %%
import pandas as pd
from pymongo import MongoClient

# Load the CSV file
csv_file_path = '/Users/shubhamrohilla/Work/Interactly Data Science Intern Project/Dataset/Candidate_data.csv' # Replace with your CSV file path
candidates_df = pd.read_csv(csv_file_path)

# Convert the job skills to list
candidates_df['Job Skills'] = candidates_df['Job Skills'].apply(lambda x: x.split(', '))

# Connect to local MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client['candidate_db']
collection = db['candidates']

# Insert data into MongoDB
candidates = candidates_df.to_dict(orient='records')
collection.insert_many(candidates)
# Out:
# InsertManyResult([ObjectId('66a66b7b9b0c02fdb7446abc'), ObjectId('66a66b7b9b0c02fdb7446abd'), ObjectId('66a66b7b9b0c02fdb7446abe'), ObjectId('66a66b7b9b0c02fdb7446abf'), ObjectId('66a66b7b9b0c02fdb7446ac0'), ObjectId('66a66b7b9b0c02fdb7446ac1'), ObjectId('66a66b7b9b0c02fdb7446ac2'), ObjectId('66a66b7b9b0c02fdb7446ac3'), ObjectId('66a66b7b9b0c02fdb7446ac4'), ObjectId('66a66b7b9b0c02fdb7446ac5'), ObjectId('66a66b7b9b0c02fdb7446ac6'), ObjectId('66a66b7b9b0c02fdb7446ac7'), ObjectId('66a66b7b9b0c02fdb7446ac8'), ObjectId('66a66b7b9b0c02fdb7446ac9'), ObjectId('66a66b7b9b0c02fdb7446aca'), ObjectId('66a66b7b9b0c02fdb7446acb'), ObjectId('66a66b7b9b0c02fdb7446acc'), ObjectId('66a66b7b9b0c02fdb7446acd'), ObjectId('66a66b7b9b0c02fdb7446ace'), ObjectId('66a66b7b9b0c02fdb7446acf'), ObjectId('66a66b7b9b0c02fdb7446ad0'), ObjectId('66a66b7b9b0c02fdb7446ad1'), ObjectId('66a66b7b9b0c02fdb7446ad2'), ObjectId('66a66b7b9b0c02fdb7446ad3'), ObjectId('66a66b7b9b0c02fdb7446ad4'), ObjectId('66a66b7b9b0c02fdb7446ad5'), ObjectId('66a66b7b9b0c02fdb7446ad6'), ObjectId('66a66b7b9b0c02fdb7446ad7'), ObjectId('66a66b7b9b0c02fdb7446ad8'), ObjectId('66a66b7b9b0c02fdb7446ad9'), ObjectId('66a66b7b9b0c02fdb7446ada'), ObjectId('66a66b7b9b0c02fdb7446adb'), ObjectId('66a66b7b9b0c02fdb7446adc'), ObjectId('66a66b7b9b0c02fdb7446add'), ObjectId('66a66b7b9b0c02fdb7446ade'), ObjectId('66a66b7b9b0c02fdb7446adf'), ObjectId('66a66b7b9b0c02fd
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = AutoModel.from_pretrained('bert-base-uncased')

print("Transformers is installed correctly.")
# Out:
# 1.13.1
# PyTorch is installed correctly.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1585         try:
# -> 1586             return importlib.import_module("." + module_name, self.__name__)
#    1587         except Exception as e:
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py in <module>
#      24 import torch
# ---> 25 import torch.utils.checkpoint
#      26 from packaging import version
#
# /opt/homebrew/lib/python3.9/site-packages/torch/utils/checkpoint.py in <module>
#      23 import torch.fx.traceback as fx_traceback
# ---> 24 from torch._functorch._aot_autograd.functional_utils import is_fun
#      25 from torch.utils._pytree import tree_map
#
# /opt/homebrew/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/functional_utils.py in <module>
#      16 from torch._subclasses.fake_tensor import FakeTensor
# ---> 17 from torch._subclasses.functional_tensor import FunctionalTensor
#      18 from torch._subclasses.meta_utils import is_sparse_any
#
# /opt/homebrew/lib/python3.9/site-packages/torch/_subclasses/functional_tensor.py in <module>
#       8 import torch.utils._pytree as pytree
# ----> 9 from torch._C import _functionalization_reapply_views_tls as _reapply_views
#      10 from torch._ops import _get_dispatch_mode_pre_dispatch
#
# ImportError: cannot import name '_functionalization_reapply_views_tls' from 'torch._C' (/opt/homebrew/lib/python3.9/site-packages/torch/_C.cpython-39-darwin.so)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /var/folders/88/tc7349753nd5q97nxk3d2d2m0000gn/T/ipykernel_58570/3383254663.py in <module>
#       6
#       7 tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# ----> 8 model = AutoModel.from_pretrained('bert-base-uncased')
#       9
#      10 print("Transformers is installed correctly.")
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561             )
#     562         elif type(config) in cls._model_mapping.keys():
# --> 563             model_class = _get_model_class(config, cls._model_mapping)
#     564             return model_class.from_pretrained(
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in _get_model_class(config, model_mapping)
#     382
#     383 def _get_model_class(config, model_mapping):
# --> 384     supported_models = model_mapping[type(config)]
#     385     if not isinstance(supported_models, (list, tuple)):
#     386         return supported_models
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in __getitem__(self, key)
#     733         if model_type in self._model_mapping:
#     734             model_name = self._model_mapping[model_type]
# --> 735             return self._load_attr_from_module(model_type, model_name)
#     736
#     737         # Maybe there was several model types associated with this config.
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in _load_attr_from_module(self, model_type, attr)
#     747         if module_name not in self._modules:
#     748             self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 749         return getattribute_from_module(self._modules[module_name], attr)
#     750
#     751     def keys(self):
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     691     if isinstance(attr, tuple):
#     692         return tuple(getattribute_from_module(module, a) for a in attr)
# --> 693     if hasattr(module, attr):
#     694         return getattr(module, attr)
#     695     # Some of the mappings have entries model_type -> object of another model type. In that case we try to grab the
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1574             value = self._get_module(name)
#    1575         elif name in self._class_to_module.keys():
# -> 1576             module = self._get_module(self._class_to_module[name])
#    1577             value = getattr(module, name)
#    1578         else:
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1586             return importlib.import_module("." + module_name, self.__name__)
#    1587         except Exception as e:
# -> 1588             raise RuntimeError(
#    1589                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1590                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.models.bert.modeling_bert because of the following error (look up to see its traceback):
# cannot import name '_functionalization_reapply_views_tls' from 'torch._C' (/opt/homebrew/lib/python3.9/site-packages/torch/_C.cpython-39-darwin.so)

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# Path to the directory where the model is saved
model_directory = "/Users/shubhamrohilla/Work/Interactly Data Science Intern Project/Code/LLM Model/fine-tuned-model"

# Load your fine-tuned model and tokenizer
model = AutoModelForSequenceClassification.from_pretrained(model_directory)
tokenizer = AutoTokenizer.from_pretrained(model_directory)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1585         try:
# -> 1586             return importlib.import_module("." + module_name, self.__name__)
#    1587         except Exception as e:
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /opt/homebrew/Cellar/python@3.9/3.9.19_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py in <module>
#      24 import torch
# ---> 25 import torch.utils.checkpoint
#      26 from packaging import version
#
# /opt/homebrew/lib/python3.9/site-packages/torch/utils/checkpoint.py in <module>
#      23 import torch.fx.traceback as fx_traceback
# ---> 24 from torch._functorch._aot_autograd.functional_utils import is_fun
#      25 from torch.utils._pytree import tree_map
#
# /opt/homebrew/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/functional_utils.py in <module>
#      16 from torch._subclasses.fake_tensor import FakeTensor
# ---> 17 from torch._subclasses.functional_tensor import FunctionalTensor
#      18 from torch._subclasses.meta_utils import is_sparse_any
#
# /opt/homebrew/lib/python3.9/site-packages/torch/_subclasses/functional_tensor.py in <module>
#       8 import torch.utils._pytree as pytree
# ----> 9 from torch._C import _functionalization_reapply_views_tls as _reapply_views
#      10 from torch._ops import _get_dispatch_mode_pre_dispatch
#
# ImportError: cannot import name '_functionalization_reapply_views_tls' from 'torch._C' (/opt/homebrew/lib/python3.9/site-packages/torch/_C.cpython-39-darwin.so)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /var/folders/88/tc7349753nd5q97nxk3d2d2m0000gn/T/ipykernel_58570/17255298.py in <module>
#       5
#       6 # Load your fine-tuned model and tokenizer
# ----> 7 model = AutoModelForSequenceClassification.from_pretrained(model_directory)
#       8 tokenizer = AutoTokenizer.from_pretrained(model_directory)
#       9
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561             )
#     562         elif type(config) in cls._model_mapping.keys():
# --> 563             model_class = _get_model_class(config, cls._model_mapping)
#     564             return model_class.from_pretrained(
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in _get_model_class(config, model_mapping)
#     382
#     383 def _get_model_class(config, model_mapping):
# --> 384     supported_models = model_mapping[type(config)]
#     385     if not isinstance(supported_models, (list, tuple)):
#     386         return supported_models
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in __getitem__(self, key)
#     733         if model_type in self._model_mapping:
#     734             model_name = self._model_mapping[model_type]
# --> 735             return self._load_attr_from_module(model_type, model_name)
#     736
#     737         # Maybe there was several model types associated with this config.
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in _load_attr_from_module(self, model_type, attr)
#     747         if module_name not in self._modules:
#     748             self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 749         return getattribute_from_module(self._modules[module_name], attr)
#     750
#     751     def keys(self):
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     691     if isinstance(attr, tuple):
#     692         return tuple(getattribute_from_module(module, a) for a in attr)
# --> 693     if hasattr(module, attr):
#     694         return getattr(module, attr)
#     695     # Some of the mappings have entries model_type -> object of another model type. In that case we try to grab the
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1574             value = self._get_module(name)
#    1575         elif name in self._class_to_module.keys():
# -> 1576             module = self._get_module(self._class_to_module[name])
#    1577             value = getattr(module, name)
#    1578         else:
#
# /opt/homebrew/lib/python3.9/site-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1586             return importlib.import_module("." + module_name, self.__name__)
#    1587         except Exception as e:
# -> 1588             raise RuntimeError(
#    1589                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1590                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.models.bert.modeling_bert because of the following error (look up to see its traceback):
# cannot import name '_functionalization_reapply_views_tls' from 'torch._C' (/opt/homebrew/lib/python3.9/site-packages/torch/_C.cpython-39-darwin.so)
